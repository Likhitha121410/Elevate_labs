# %% [markdown]
# <a href="https://colab.research.google.com/github/Likhitha121410/Elevate_labs/blob/main/DATA_CLEANING.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# Load the dataset
df = pd.read_csv("/content/CLEANED_DATA.csv")
# Display first 5 rows
print(df.head())
# Display dataset information
print(df.info())
# Check missing values
print("\nMissing Values:")
print(df.isnull().sum())
# Check duplicate rows
print("\nDuplicate Rows:", df.duplicated().sum())
# Display data types
print("\nData Types:")
print(df.dtypes)
# Display summary statistics
print("\nSummary Statistics:")
print(df.describe(include='all'))
# Out:
#    user id                        product id Interaction type  \
# 0        1  4c69b61db1fc16e7013b43fc926e502d         purchase
# 1        2  66d49bbed043f5be260fa9f7fbff5957             view
# 2        3  2c55cae269aebf53838484b0d7dd931a             like
# 3        4  18018b6bc416dab347b1b7db79994afa             view
# 4        5  e04b990e95bf73bbe6a3fa09785d7cd0             like
#
#          Time stamp  Unnamed: 4
# 0  10-10-2023 08:00         NaN
# 1  11-10-2023 08:00         NaN
# 2  12-10-2023 08:00         NaN
# 3  13-10-2023 08:00         NaN
# 4  14-10-2023 08:00         NaN
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2999 entries, 0 to 2998
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   user id           2999 non-null   int64
#  1   product id        2999 non-null   object
#  2   Interaction type  2871 non-null   object
#  3   Time stamp        2999 non-null   object
# ...

# %%
df.to_csv("cleaned_dataset.csv", index=False)
print("File saved successfully!")
# Out:
# File saved successfully!
